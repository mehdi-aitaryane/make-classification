# %%
from datasets import make_classification, count_occurances, print_shape
from plots import scatter2D, scatter3D

# %%
X, y = make_classification(n_samples=10000, n_features=2, n_classes=2, noise=0.0, balanced=True, random_state=555)

# %%
print_shape(X, y)
# Out:
# X shape is  (10000, 2)
# y shape is  (10000,)

# %%
count_occurances(y)
# Out:
# class  0  has  5029  items
# class  1  has  4971  items

# %%
title = "2D Balanced Synthetic Dataset For Binary Classification"
xlabel = "Feature 1"
ylabel = "Feature 2"
scatter2D(title, xlabel, ylabel, X, y)

# %%
X, y = make_classification(n_samples=10000, n_features=2, n_classes=2, noise=0.0, balanced=False, random_state=74)

# %%
print_shape(X, y)
# Out:
# X shape is  (10000, 2)
# y shape is  (10000,)

# %%
count_occurances(y)
# Out:
# class  0  has  1996  items
# class  1  has  8004  items

# %%
title = "2D Unbalanced Synthetic Dataset For Binary Classification"
xlabel = "Feature 1"
ylabel = "Feature 2"
scatter2D(title, xlabel, ylabel, X, y)

# %%
X, y = make_classification(n_samples=986, n_features=3, n_classes=4, noise=0.0, balanced=True, random_state=111)

# %%
print_shape(X, y)
# Out:
# X shape is  (986, 3)
# y shape is  (986,)

# %%
count_occurances(y)
# Out:
# class  0  has  255  items
# class  1  has  262  items
# class  2  has  227  items
# class  3  has  242  items

# %%
title = "3D Balanced Synthetic Dataset For Multi Classification"
xlabel = "Feature 1"
ylabel = "Feature 2"
zlabel = "Feature 3"
scatter3D(title, xlabel, ylabel, zlabel, X, y)

# %%
X, y = make_classification(n_samples=2000, n_features=2, n_classes=10, noise=100.0, balanced=False, random_state=333)

# %%
print_shape(X, y)
# Out:
# X shape is  (2000, 2)
# y shape is  (2000,)

# %%
count_occurances(y)
# Out:
# class  0  has  320  items
# class  1  has  446  items
# class  2  has  8  items
# class  3  has  195  items
# class  4  has  221  items
# class  5  has  26  items
# class  6  has  55  items
# class  7  has  61  items
# class  8  has  126  items
# class  9  has  542  items

# %%
title = "2D Unbalanced Synthetic Dataset For Multi Classification"
xlabel = "Feature 1"
ylabel = "Feature 2"
scatter2D(title, xlabel, ylabel, X, y)

# %%
X, y = make_classification(n_samples=10000, n_features=3, n_classes=2, noise=100.0, balanced=False, random_state=999)

# %%
print_shape(X, y)
# Out:
# X shape is  (10000, 3)
# y shape is  (10000,)

# %%
count_occurances(y)
# Out:
# class  0  has  6118  items
# class  1  has  3882  items

# %%
title = "3D Unbalanced Synthetic Dataset For Multi Classification With Noise"
xlabel = 'Feature 1'
ylabel = 'Feature 2'
zlabel = 'Feature 3'
scatter3D(title, xlabel, ylabel, zlabel, X, y)
